# %%
import zipfile
import os

zip_file_path = '/content/drive/MyDrive/manipulator_project_dataset.zip'
extract_folder_path = 'dataset_yolo'

os.makedirs(extract_folder_path, exist_ok=True)

with zipfile.ZipFile(zip_file_path) as zip_ref:
    zip_ref.extractall(extract_folder_path)

# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.6/914.6 kB 24.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 107.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 94.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import os

project_folder_path = '/content/dataset_yolo/manipulator_project_dataset/images/train'

files_and_folders = os.listdir(project_folder_path)

num_elements = len(files_and_folders)

print("Elements number:", num_elements)
# Out:
# Elements number: 30929

# %%
import os

folder_path = 'dataset_yolo/manipulator_project_dataset/labels/train'
files = os.listdir(folder_path)

for file in files:
    file_path = os.path.join(folder_path, file)
    os.remove(file_path)

# %%
import sys
import os
import torch
from ultralytics import YOLO
from google.colab import files

def train_model():
    if torch.cuda.is_available():
        device = '0'
    else:
        raise ValueError("CUDA device not available. Please check your CUDA installation.")

    model = YOLO("yolov8m.pt")
    results = model.train(
        data="/content/dataset_yolo/manipulator_project_dataset/data.yaml",
        epochs=100,
        imgsz=640,
        patience=10,
        lr0=0.01,
        lrf=0.01,
        batch=24,
        device=device,
        workers=8,
        optimizer='AdamW',
        weight_decay=0.0005,
        warmup_epochs=3.0,
        warmup_bias_lr=0.05,
        box=7.5,
        cls=0.5,
        dfl=1.5,
        mosaic=1.0,
        mixup=0.1,
        hsv_h=0.015,
        hsv_s=0.7,
        hsv_v=0.4,
        flipud=0.0,
        fliplr=0.5,
        dropout=0.05
    )

if __name__ == '__main__':
    train_model()
    files.download('/content/runs/detect/train/weights/best.pt')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 318MB/s]
# Ultralytics 8.3.73 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
